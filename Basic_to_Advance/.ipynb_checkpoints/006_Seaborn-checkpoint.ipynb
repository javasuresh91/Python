# %% [markdown]
# # Seaborn
#
# ## Distribution Plots
#
#     Displot
#     joinplot
#     pairplot
# Practise Problem on IRIS dataset
#
# Uni-Varient Analysis : Only one feature is involved for the analysis
#
# Bi-Varient Analysis :Two Features are involved for the analysis in the given dataset

# %%
import seaborn as sns

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# In above data set
# tips  ==> Dependent features
# rate, sex, smoker, daya ===> Independent Features

# %% [markdown]
# # Correlation with Heatmap
#
#     A Correlation heatmap uses colored cells, typically in a monochromatic scale , to show 2D correlation matrix (table) between two discrete dimensions or event types. It is very important in feature selection.
#
#     Correlation can be find on the floating/integer values not in the categorical values(Object Type)
#
# ## Correlation means fidning the inter-relationship between given features

# %%
print(df.dtypes)
df.corr()
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Join Plot
#
# A join Plot allows to study the relationship between two numerical variables. The central chart display their correlation. It is usually a scatterplot , a hexbin plot , a 2D histogram or a 2D Density plot

# %% [markdown]
# ## Bi- Variate Analysis

# %%
sns.jointplot(x="tip",y="total_bill",data=df,kind='hex')

# %%
sns.jointplot(x="tip",y="total_bill",data=df,kind='reg') ## Draw a regression line

# %% [markdown]
# ## Pair Plot
#
# A "pair plot" is also knowns as  a scatter plot, in which one variable in the same data row is matched with another variable's value, like this: Pairs plots are just elaboration on this, showing all variables paired with all the other variables

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue="sex")

# %% [markdown]
# ## Dist Plot
#
# Dist Plot helps us to check the distribution of the column features

# %%
sns.displot(df['tip'])

# %%
sns.displot(df['tip'],kde=False, bins=10)

# %% [markdown]
# # Categorical Plot
#
#     Seaborn also helps us in doing the analysis on the categorical data points. In this section we will discuss about
#
#         Box Plot
#         Violin Plot
#         count Plot
#         bar Plot

# %% [markdown]
# ## Count Plot

# %%
sns.countplot("sex",data=df)
# Out:
# G:\Datascience\installation\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot("smoker",data=df)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot("day",data=df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.countplot("time",data=df)
# Out:
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
sns.countplot(y="time",data=df) ## Change the axis direction
# Out:
# <AxesSubplot:xlabel='count', ylabel='time'>

# %% [markdown]
# ## Bar Plot

# %%
sns.barplot(x='total_bill',y='sex',data=df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='sex'>

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot('sex','total_bill',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot('day','total_bill',data=df,palette='rainbow')
# Out:
# G:\Datascience\installation\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
